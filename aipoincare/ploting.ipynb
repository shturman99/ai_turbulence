# %%
import numpy as np
import matplotlib.pyplot as plt


x_arr = []
p_arr = []
with open("backend/data/oned_harmonic") as f:
    for line in f:
        x, p = line.split()
        x = float(x)
        p = float(p)
        x_arr.append(x)
        p_arr.append(p)

# %%
plt.plot(p_arr)

# %%
len(p_arr)
# Out:
# 1000
